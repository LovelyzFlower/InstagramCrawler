# %%
from selenium import webdriver
import time
import csv
f = open('data.csv','w',encoding='utf-8',newline='')
wr = csv.writer(f)
path ="chromedriver.exe"
driver=webdriver.Chrome(path)

def login():
    driver.get("https://www.instagram.com/accounts/login")
    element_id = driver.find_element_by_name("username")
    element_pw = driver.find_element_by_name("password")

    element_id.send_keys("asjie3315@gmail.com")
    element_pw.send_keys("lee3315")
    element_pw.submit()

    time.sleep(10)
    element_later = driver.find_element_by_xpath('//*[@id="react-root"]/div/div[2]/a[2]')
    element_later.click()
def process(item_name):
    element_item = driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input')
    element_item.send_keys("#"+item_name)
    try:
        time.sleep(5)
        element_click = driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/div[2]/div[2]/div/a[1]')
        element_click.click()

        time.sleep(5)
        element_pic = driver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div[1]/div[2]')
        element_pic.click()
        time.sleep(3)
        content = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/div[2]/div[1]/ul').text

        slice_list=content.split(" ")
        for s in slice_list:
            if s:
                if s[0]=="#":
                    wr.writerow([s])
                    print(s)

        element_pic = driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div/div/a')
        element_pic.click()
        time.sleep(2)

        for i in range(0,30):
            content = driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/div[2]/div[1]/ul').text

            slice_list=content.split(" ")
            for s in slice_list:
                if s:
                    if s[0]=="#":
                        wr.writerow([s])
                        print(s)

            element_pic = driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div/div/a[2]')
            element_pic.click()
            time.sleep(2)

        f.close()
        print("Done!")
    except Exception as e:
        print(e)
    
def main():
    login()
    process("1984나폴리")
    
if __name__=="__main__":
        main()
# Out:
# #부산
# #서면
# #1984나폴리
# #아이존팝
# ___minki지리는고만ㅎㅎ
# jihyeong_park@___minki
# #1984나폴리
# #1984나폴리
# i_i_im_yujin리조또
# #서면#1984나폴리
# holyvible아이폰아
# #전포카페거리
# #1984나폴리
# #엑스트라마르게리따
# #뽀모도로모짜
# #피자
# #파스타
# #먹스타그램
# #남산동
# #도다지그램
# #도다지1주년
# #보고싶다
# #완전체
# #언제모여
# jem113굿입니다!!👍😃👍👍
# kyh6344k잘
# #포괄후
# #뽄지기고
# #오빠만나러
# #전포카페거리
# #1984나폴리
# #잘먹어써요오
# #내사랑꾼❤️
# #부끄러웠다
# #합성동
# #로프트커피
# #심쿵
# #셀스타그램
# #인스타그램
# #일상
# #부산
# #마산
# #좋아요
# d_dahye_b이쁜얼굴
# #까르보나라파스타
# #1984나폴리
# #양산맛집
# #같이먹은메뉴는이름을못외움
# #덩달아맛있었는데
# #내입맛집
# #맛있는거맛있게먹고서로의시간과이야기를공유하고
# #좋은날
# #180519
# #고맙고미안하고
# #내가언니인데정신연령은나보다더언니같은동생이랑
# #book
# #read
# #target
# #achieve
# #george
# #georgeorwell
# #1984
# #1984georgeorwell
# #1984나폴리
# #neverforget1984
# #joulia
# #weniston
# #obrian
# #giveup
# #bookstagram
# #books
# #story
# #instabook
# #book
# #رواية
# #١٩٨٤
# #جورج_اورول
# sami_mustafa_الرواية
# #햄토리나폴리1984
# 피자랑
# #남산동
# #남산동맛집
# #부산외대맛집
# #피자
# #피자맛집
# #오일파스타
# #오일파스타맛집
# #엔초비파스타
# #엔초비
# #루꼴라피자
# #상그리아
# #루꼴라피자맛집
# #파스타
# ...
